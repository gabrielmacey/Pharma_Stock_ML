# %%
# Must have pandas, pymongo, and yfinace installed on environment
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
#API calls
#AstraZeneca
azn = yf.Ticker("AZN")
#Bristol Myers Squibb
bmy = yf.Ticker("BMY")
#Johnson & Johnson
jnj = yf.Ticker("JNJ")
#Merck
mrk = yf.Ticker("MRK")
#Pfizer
pfe = yf.Ticker("PFE")

# %%
#Extracting history data from stocks (parameters can change)
#Period parameters - 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
#Interval parameters - 1m, 2m, 5m, 15m, 30m, 1h, 1d, 5d, 1wk, 1mo, 3mo
azn_data = azn.history(interval="1d", period="10y")
bmy_data = bmy.history(interval="1d", period="10y")
jnj_data = jnj.history(interval="1d", period="10y")
mrk_data = mrk.history(interval="1d", period="10y")
pfe_data = pfe.history(interval="1d", period="10y")

# %%
#Converting to a DataFrame
azn_df = pd.DataFrame(azn_data)
bmy_df = pd.DataFrame(bmy_data)
jnj_df = pd.DataFrame(jnj_data)
mrk_df = pd.DataFrame(mrk_data)
pfe_df = pd.DataFrame(pfe_data)

# %%
#Inserting an identifier to know which stock the information came from
azn_df.insert(0, 'stock_name', 'AZN')
bmy_df.insert(0, 'stock_name', 'BMY')
jnj_df.insert(0, 'stock_name', 'JNJ')
mrk_df.insert(0, 'stock_name', 'MRK')
pfe_df.insert(0, 'stock_name', 'PFE')

# %%
#Add DataFrames to a list
dataframes = [azn_df, bmy_df, jnj_df, mrk_df, pfe_df]
#Concatinate this list into one DataFrame
stock_df = pd.concat(dataframes)

# %%
#Reset index
stock_df.reset_index(inplace=True)

# %%
#Remove unnecessary columns
stock_df.drop(["Dividends", "Stock Splits"], axis=1, inplace=True)

# %%
stock_df.rename(columns={"Date":"date", 
                         "Open": "open", 
                         "High": "high",
                         "Low": "low",
                         "Close": "close", 
                         "Volume": "volume",}, inplace=True)

# %%
stock_df
# Out:
#             date stock_name       open       high        low      close  \
# 0     2011-03-04        AZN  15.860339  15.909001  15.707866  15.837630
# 1     2011-03-07        AZN  15.850608  15.853852  15.636498  15.665695
# 2     2011-03-08        AZN  15.548910  15.613792  15.500248  15.561887
# 3     2011-03-09        AZN  15.678674  15.698137  15.607303  15.652720
# 4     2011-03-10        AZN  15.552153  15.617035  15.506736  15.529445
# ...          ...        ...        ...        ...        ...        ...
# 12575 2021-02-25        PFE  33.820000  34.110001  33.540001  33.820000
# 12576 2021-02-26        PFE  33.840000  33.900002  33.360001  33.490002
# 12577 2021-03-01        PFE  33.590000  33.930000  33.509998  33.689999
# 12578 2021-03-02        PFE  33.680000  33.889999  33.500000  33.509998
# 12579 2021-03-03        PFE  33.509998  34.449902  33.439999  34.389999
#
#          volume
# 0       1505400
# 1       1762200
# 2       1858800
# 3       2595600
# 4       2364200
# ...         ...
# 12575  37506100
# 12576  41418100
# 12577  30176500
# 12578  27621600
# 12579  44241247
#
# [12580 rows x 7 columns]

# %%
stock_df['date'] = pd.to_datetime(stock_df['date'])
# Out:
#             date stock_name       open       high        low      close  \
# 0     2011-03-04        AZN  15.860339  15.909001  15.707866  15.837630
# 1     2011-03-07        AZN  15.850608  15.853852  15.636498  15.665695
# 2     2011-03-08        AZN  15.548910  15.613792  15.500248  15.561887
# 3     2011-03-09        AZN  15.678674  15.698137  15.607303  15.652720
# 4     2011-03-10        AZN  15.552153  15.617035  15.506736  15.529445
# ...          ...        ...        ...        ...        ...        ...
# 12575 2021-02-25        PFE  33.820000  34.110001  33.540001  33.820000
# 12576 2021-02-26        PFE  33.840000  33.900002  33.360001  33.490002
# 12577 2021-03-01        PFE  33.590000  33.930000  33.509998  33.689999
# 12578 2021-03-02        PFE  33.680000  33.889999  33.500000  33.509998
# 12579 2021-03-03        PFE  33.509998  34.449902  33.439999  34.389999
#
#          volume
# 0       1505400
# 1       1762200
# 2       1858800
# 3       2595600
# 4       2364200
# ...         ...
# 12575  37506100
# 12576  41418100
# 12577  30176500
# 12578  27621600
# 12579  44241247
#
# [12580 rows x 7 columns]

# %%
from pandas.plotting import lag_plot
import numpy as np
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
azn_df = stock_df[stock_df['stock_name'] == 'AZN']
#azn_df = azn_df.set_index('date')
azn_df
# Out:
#            date stock_name       open       high        low      close  \
# 0    2011-03-04        AZN  15.860339  15.909001  15.707866  15.837630
# 1    2011-03-07        AZN  15.850608  15.853852  15.636498  15.665695
# 2    2011-03-08        AZN  15.548910  15.613792  15.500248  15.561887
# 3    2011-03-09        AZN  15.678674  15.698137  15.607303  15.652720
# 4    2011-03-10        AZN  15.552153  15.617035  15.506736  15.529445
# ...         ...        ...        ...        ...        ...        ...
# 2511 2021-02-25        AZN  49.849998  49.869999  48.750000  48.910000
# 2512 2021-02-26        AZN  48.849998  48.919998  47.980000  48.380001
# 2513 2021-03-01        AZN  48.459999  48.680000  48.080002  48.090000
# 2514 2021-03-02        AZN  48.400002  48.430000  47.669998  47.730000
# 2515 2021-03-03        AZN  47.639999  47.639999  46.845001  47.160000
#
#         volume
# 0      1505400
# 1      1762200
# 2      1858800
# 3      2595600
# 4      2364200
# ...        ...
# 2511  12795900
# 2512   8547800
# 2513  11374500
# 2514  14356500
# 2515  14031515
#
# [2516 rows x 7 columns]

# %%
azn_df.isnull().sum()
# Out:
# date          0
# stock_name    0
# open          0
# high          0
# low           0
# close         0
# volume        0
# dtype: int64

# %%
azn_df.shape
# Out:
# (2516, 7)

# %%
azn_df.corr()
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999780  0.999736  0.999565  0.222858
# high    0.999780  1.000000  0.999635  0.999772  0.227759
# low     0.999736  0.999635  1.000000  0.999787  0.215332
# close   0.999565  0.999772  0.999787  1.000000  0.220464
# volume  0.222858  0.227759  0.215332  0.220464  1.000000

# %%
plt.figure(figsize=(16,8))
lag_plot(azn_df['open'], lag=5)
plt.title('AZN Stock - Autocorrelation plot with lag = 5')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(azn_df["date"], azn_df["close"])
xticks = pd.date_range(datetime.datetime(2010,1,1), datetime.datetime(2021,1,1), freq='YS')
xticks=xticks.to_pydatetime()
plt.xticks(xticks)
plt.title("AZN stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.show()

# %%
X_train = azn_df[:1800]
X_train = X_train.set_index('date')
X_test = azn_df[1801:]
X_test = X_test.set_index('date')
X_test
# Out:
#            stock_name       open       high        low      close    volume
# date
# 2018-05-01        AZN  32.560346  32.980011  32.377887  32.970886   6419000
# 2018-05-02        AZN  32.688079  32.834048  32.396136  32.423508   5403400
# 2018-05-03        AZN  32.669834  32.779310  32.405263  32.678955   4985100
# 2018-05-04        AZN  32.396127  32.615082  32.295775  32.459991   5477500
# 2018-05-07        AZN  32.633337  32.925276  32.560350  32.815800   3168700
# ...               ...        ...        ...        ...        ...       ...
# 2021-02-25        AZN  49.849998  49.869999  48.750000  48.910000  12795900
# 2021-02-26        AZN  48.849998  48.919998  47.980000  48.380001   8547800
# 2021-03-01        AZN  48.459999  48.680000  48.080002  48.090000  11374500
# 2021-03-02        AZN  48.400002  48.430000  47.669998  47.730000  14356500
# 2021-03-03        AZN  47.639999  47.639999  46.845001  47.160000  14031515
#
# [715 rows x 6 columns]

# %%
plt.figure(figsize=(12,8))
ax=X_train.plot(grid=True, figsize=(12,8))
X_test.plot(ax=ax,grid=True)
plt.legend(['X_test', 'X_train'])
plt.show()

# %%
X_train, X_test = azn_df[0:int(len(azn_df)*0.8)], azn_df[int(len(df)*0.8):]
training_data = X_train['close'].values
test_data = X_test['close'].values

# %%
import warnings
warnings.filterwarnings('ignore')
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 0.5880094040987398

# %%
test_set_range = azn_df[int(len(azn_df)*0.7):].index
test_set_range
# Out:
# Int64Index([1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770,
#             ...
#             2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513, 2514, 2515],
#            dtype='int64', length=755)

# %%
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('TESLA Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(881,1259,50), df.Date[881:1259:50])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-a309af0cd71d> in <module>
# ----> 1 plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
#       2 plt.plot(test_set_range, test_data, color='red', label='Actual Price')
#       3 plt.title('TESLA Prices Prediction')
#       4 plt.xlabel('Date')
#       5 plt.ylabel('Prices')
#
# ~/anaconda3/envs/PythonDataAdv/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~/anaconda3/envs/PythonDataAdv/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/anaconda3/envs/PythonDataAdv/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/anaconda3/envs/PythonDataAdv/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (755,) and (715, 1)
